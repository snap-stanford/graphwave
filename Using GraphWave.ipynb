# %% [markdown]
# <center> <h1>Using GraphWave </h1> </center>
#
# &nbsp;
#
# &nbsp;
#
# The goal of the  following notebook is to show how the GraphWave algorithm can be used.
#
# GraphWave was implemented in Python 2.7 and requires to load the following Python packages:
#
# + __pygsp__ (Graph signal Processing package from EPFL, to compute spectral graph wavelets.)
# + __pyemd__ (for computing EMD distances)
# + __networkx__ (for handling network objects: in particular, visualization, etc.)
# + traditional libraries for data analytics: __seaborn__ for plotting, __pandas__ for dataframes

# %%
# %matplotlib inline
import networkx as nx 
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
import matplotlib.pyplot as plt
import sys,os
from GraphWave import *
import seaborn as sb


from GraphWave import shapes,graphwave, heat_diffusion,characteristic_functions

from GraphWave.shapes import build_graph,shapes
from GraphWave.heat_diffusion import *
from GraphWave.utils.graph_tools  import *
from GraphWave.utils.utils import *
from GraphWave.characteristic_functions import *

# %% [markdown]
# ## I. Creating a graph

# %%
# 1- Start by defining our favorite regular structure

width_basis=15
nbTrials=20


################################### EXAMPLE TO BUILD A SIMPLE REGULAR STRUCTURE ##########
## REGULAR STRUCTURE: the most simple structure:  basis + n small patterns of a single type

### 1. Choose the basis (cycle, torus or chain)
basis_type="cycle" 

### 2. Add the shapes 
nb_shapes=5  ## numbers of shapes to add 
#shape=["fan",6] ## shapes and their associated required parameters  (nb of edges for the star, etc)
#shape=["star",6]
shape=["house"]

### 3. Give a name to the graph
identifier='AA'  ## just a name to distinguish between different trials
name_graph='houses'+ identifier
sb.set_style('white')

### 4. Pass all these parameters to the Graph Structure
add_edges=0
del_edges=0
G,colors=build_graph.build_regular_structure(width_basis,basis_type, nb_shapes,shape, start=0,add_random_edges=add_edges,plot=True,savefig=False)

# %%
nx.draw(G)

# %% [markdown]
# (Note: best visualization of the graphs are obtained using Gephi, or some other specialized graph visualization software)

# %% [markdown]
# ## II. Running GraphWave
#
#
# We propose here a simple demonstration of GraphWave using both the automatic version (part a) and the manual version. This shows how to use GraphWave in a parameter-free version, or giving the analyst the possibility to select an adequate scale value.
#
# For each of these approaches, we compute the signature by calling GraphWave. We then compute its PCA projection to visualize the embeddings. Note that in this very simple examples, GraphWave recovers structura equivalence, as shown by the overlapping embeddings on the first principal components.
#
# #### a. Multiscale GraphWave: Automatic selection of the range of scales

# %%
from GraphWave.graphwave import *
taus=range(1,10)

# %%
chi,heat_print, taus=graphwave(G, 'automatic', verbose=False)
# Out:
# 2017-11-05 10:18:15,721:[INFO](pygsp.filters.filter.__init__): Heat : has to compute lmax
# 2017-11-05 10:18:15,747:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:15,770:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:15,781:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:15,797:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:15,814:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:15,833:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:15,844:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:15,857:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:15,872:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:15,890:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:15,910:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:15,928:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:15,948:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:15,969:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:15,986:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,006:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,028:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,046:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,058:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,072:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,091:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,110:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,122:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,134:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,143:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,155:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,165:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,175:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,188:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,200:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,217:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,228:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,239:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,252:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,264:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,276:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,287:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,301:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,314:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:16,326:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby

# %% [markdown]
# We now visualize the resulting embeddings by computing their PCA projections. We also run KMeans to assess how well the signatures that we have here generated enable the recovery of structural roles.

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
nb_clust=len(np.unique(colors))
pca=PCA(n_components=5)
trans_data=pca.fit_transform(StandardScaler().fit_transform(chi))
km=sk.cluster.KMeans(n_clusters=nb_clust)
km.fit(trans_data)
labels_pred=km.labels_
######## Params for plotting
cmapx=plt.get_cmap('rainbow')
x=np.linspace(0,1,np.max(labels_pred)+1)
col=[cmapx(xx) for xx in x ]
markers = {0:'*',1: '.', 2:',',3: 'o',4: 'v',5: '^',6: '<',7: '>',8: 3 ,9:'d',10: '+',11:'x',12:'D',13: '|',14: '_',15:4,16:0,17:1,18:2,19:6,20:7}
########

for c in np.unique(colors):
        indc=[i for i,x in enumerate(colors) if x==c]
        #print indc
        plt.scatter(trans_data[indc,0], trans_data[indc,1],c=np.array(col)[list(np.array(labels_pred)[indc])] ,marker=markers[c%len(markers)],s=500)
labels = colors
for label,c, x, y in zip(labels,labels_pred, trans_data[:, 0], trans_data[:, 1]):
            plt.annotate(label,xy=(x, y), xytext=(0, 0), textcoords='offset points')

# %% [markdown]
# #### Uniscale GraphWave: Hand-selected value for tau

# %%
### Select a scale of interest (here we select a particular range of scale. See associated paper for 
### guidelines on how to select the appropriate scale.)

### Compute the heat wavelet
chi,heat_print, taus=graphwave(G, [1], t=list(np.arange(0,100,0.5)), verbose=False)
# Out:
# 2017-11-05 10:18:20,402:[INFO](pygsp.filters.filter.__init__): Heat : has to compute lmax
# 2017-11-05 10:18:20,406:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,410:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,413:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,417:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,423:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,428:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,432:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,436:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,450:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,460:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,469:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,478:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,489:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,501:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,508:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,513:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,518:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,524:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,531:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,535:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,539:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,546:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,550:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,556:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,563:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,568:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,579:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,585:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,590:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,593:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,596:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,601:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,609:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,617:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,625:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,633:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,639:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,645:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,650:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby
# 2017-11-05 10:18:20,656:[INFO](pygsp.filters.filter.analysis): The analysis method is cheby

# %% [markdown]
# Note that in the EPFL implementation, by construction, the wavelet scales are all divided by the maximum eigenvalue $\lambda_N$.

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
nb_clust=len(np.unique(colors))
pca=PCA(n_components=5)
trans_data=pca.fit_transform(StandardScaler().fit_transform(chi))
km=sk.cluster.KMeans(n_clusters=nb_clust)
km.fit(trans_data)
labels_pred=km.labels_
######## Params for plotting
cmapx=plt.get_cmap('rainbow')
x=np.linspace(0,1,np.max(labels_pred)+1)
col=[cmapx(xx) for xx in x ]
markers = {0:'*',1: '.', 2:',',3: 'o',4: 'v',5: '^',6: '<',7: '>',8: 3 ,9:'d',10: '+',11:'x',12:'D',13: '|',14: '_',15:4,16:0,17:1,18:2,19:6,20:7}
########

for c in np.unique(colors):
        indc=[i for i,x in enumerate(colors) if x==c]
        #print indc
        plt.scatter(trans_data[indc,0], trans_data[indc,1],c=np.array(col)[list(np.array(labels_pred)[indc])] ,marker=markers[c%len(markers)],s=500)
labels = colors
for label,c, x, y in zip(labels,labels_pred, trans_data[:, 0], trans_data[:, 1]):
            plt.annotate(label,xy=(x, y), xytext=(0, 0), textcoords='offset points')

# %% [markdown]
# ## III. Visualizing the Characteristic functions
#
# We now propose to show how to visualize characteristic functions.

# %%
cmap=plt.get_cmap('gnuplot')
colors_plot=[cmap(x) for x in np.linspace(0,1,len(np.unique(colors)))]
plt.figure()
ind_x=range(chi[0].shape[0])[0::2]
ind_y=range(chi[0].shape[0])[1::2]
for i in np.random.choice(range(G.number_of_nodes()),10,replace=False):
    print i
    plt.plot(chi[i][ind_x],chi[i][ind_y],label=str(i),color=colors_plot[colors[i]])
plt.legend(loc='center left',bbox_to_anchor=(1,0.5))
# Out:
# 14
# 2
# 30
# 17
# 16
# 31
# 38
# 13
# 18
# 9
